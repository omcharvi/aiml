# %%
class bankaccount:
    def __init__ (self, account_holder, account_number, balance = 0):
        self.account_holder = account_holder
        self.account_number = account_number
        self.balance = balance

    def deposit( self, amount):
        self.balance = self.balance + amount
        return self.balance
    
    def withdraw (self,amount):
        if amount > self.balance :
            return "insufficient balalnce"
        else:
            self.balance = self.balance - amount
            return self.balance

# %%
om = bankaccount("om Kashyap", 2325235214,)

# %%
om.balance
# Out:
# 0

# %%
om.account_holder
# Out:
# 'om Kashyap'

# %%
om.account_number
# Out:
# 2325235214

# %%
om.deposit(600)
# Out:
# 600

# %%
om.balance
# Out:
# 600

# %%
om.withdraw(540)
# Out:
# 60

# %%
om.balance
# Out:
# 60

# %%
om.withdraw(4534)
# Out:
# 'insufficient balalnce'

# %%
class shoppincart:
    def __init__(self, customer_name):
        self.customer_name = customer_name
        self.items= []

# %%
class bankaccount:
    def __init__ (self,account_holder, account_name, balance = 0):
        self.account_holder = account_holder
        self.account_name = account_name
        self.balace = balance

    def deposit (self,amount):
        self.balace = self.balace +amount
        return self.balace 
    
    def withdraw (self, amount):
        if amount > self.balace:
            return "insufficient amount!!"
        else:
            self.balace = self.balace - amount
            return self.balace

# %%
chitranjan = bankaccount("Chitranjan Kumar", 30191327592)

# %%
chitranjan.balace
# Out:
# 0

# %%
chitranjan.deposit(430)
# Out:
# 430

# %%
chitranjan.balace
# Out:
# 430

# %%
chitranjan.withdraw(400)
# Out:
# 30

# %%
chitranjan.balace
# Out:
# 30

# %%
chitranjan.account_holder
# Out:
# 'Chitranjan Kumar'

# %%
chitranjan.account_name
# Out:
# 30191327592

# %%
class Member:
    def __init__(self, name, age, membership_type):
        self.name = name
        self.age = age
        self.membership_type = membership_type
        
    def __str__(self):
        return f"Name: {self.name}, Age : {self.age}, Membership Type : {self.membership_type}"
    
members_details = [
        ("Atulit kashyap", 26, "Yearly"),
        ("Charvi", 30, "quartely"),
        ("kavit kumar", 33, "monthly"),
        ("Chitranjan kumar", 35 , "Monhtly"),
        ("Kaushal kumar", 40, "Yearly")
    ]
    
member_list= []

    for details in members_details:
        member = Member(*details)
        member_list.append(member)

    for m in member_list:
        print(m)
# Out:
# Name: Atulit kashyap, Age : 26, Membership Type : Yearly
# Name: Charvi, Age : 30, Membership Type : quartely
# Name: kavit kumar, Age : 33, Membership Type : monthly
# Name: Chitranjan kumar, Age : 35, Membership Type : Monhtly
# Name: Kaushal kumar, Age : 40, Membership Type : Yearly
