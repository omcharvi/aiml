# %%
1
# Out:
# 1

# %%
i = 10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 i = 10/0
#
# ZeroDivisionError: division by zero

# %%
i= int(input("tyr to  input an intiger"))
b = 10/ i
print("10 devided by your input is", b)
# Out:
# 10 devided by your input is 0.11494252873563218

# %%
try :
    print("welcome to calculator from euron")
    try :
        a = int(input("enter first number : "))
        b = int(input("enter second number : "))
        try :
            op = input("enter operator (+ , - , * , / ) : ")
            if op == "+" :
                print("addition is " , a + b)
            elif op == "-" :
                print("subtraction is " , a - b)
            elif op == "*" :
                print("multiplication is " , a * b)
            elif op == "/" :
                print("division is " , a / b)
            else :
                print("invalid operator")
        except Exception as e :
            print("inner most except block :" , e)
    except Exception as e :
        print("inner except block :" , e)
except Exception as e :
    print("outer except block :" , e)
finally:
    print("thank you for using euron calculator")
# Out:
# welcome to calculator from euron
# inner except block : invalid literal for int() with base 10: '+887t78'
# thank you for using euron calculator
