# %%
a =10 
b = 20

# %%
c= a+b 
print (c)
# Out:
# 30

# %%
d= b-a
print(d)
# Out:
# 10

# %%
e = a*b
print (e)
# Out:
# 200

# %%
f = a/b
print(f)
# Out:
# 0.5

# %%
a = 4
b = 6

# %%
c = a , b = b,a
print (a, b)
# Out:
# 6 4

# %%
s = "Hello my name is chitranjan and my age is 35"
print(s)
# Out:
# Hello my name is chitranjan and my age is 35

# %%
r = 5

# %%
p = 1000
r = 2
t = 3 
si = p*r*t /100 
print (si)
print (p+si)
# Out:
# 60.0
# 1060.0

# %%
l = ['apple', 'banana', 'cherry', 'guava', 'papaya']

# %%
print (l)
# Out:
# ['apple', 'banana', 'cherry', 'guava', 'papaya']

# %%
l[0], l[4]
# Out:
# ('apple', 'papaya')

# %%
l.append("pineapple")

# %%
l
# Out:
# ['apple', 'banana', 'cherry', 'guava', 'papaya', 'pineapple']

# %%
l.remove("banana")

# %%
l
# Out:
# ['apple', 'cherry', 'guava', 'papaya', 'pineapple']

# %%
t =("black", "green", "pink", "yellow,", "orange")

# %%
t
# Out:
# ('black', 'green', 'pink', 'yellow,', 'orange')

# %%
t[2], t[4]
# Out:
# ('pink', 'orange')

# %%
t.append("purple")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 t.append("purple")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t.index(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 t.index(0)
#
# ValueError: tuple.index(x): x not in tuple

# %%
list (t)
# Out:
# ['black', 'green', 'pink', 'yellow,', 'orange']

# %%
l.append("dragon fruit")

# %%
l
# Out:
# ['apple', 'cherry', 'guava', 'papaya', 'pineapple', 'dragon fruit']

# %%
tuple(l)
# Out:
# ('apple', 'cherry', 'guava', 'papaya', 'pineapple', 'dragon fruit')

# %%
d = {"Student1": "Roshan", "Stu1 Marks" : 100,  "Student2": "Lokesh", "stu2 Marks": 202, "Student3":"Vikash" ,"Stu3 Marks": 303}

# %%
d
# Out:
# {'Student1': 'Roshan',
#  'Stu1 Marks': 100,
#  'Student2': 'Lokesh',
#  'stu2 Marks': 202,
#  'Student3': 'Vikash',
#  'Stu3 Marks': 303}

# %%
d.keys()
# Out:
# dict_keys(['Student1', 'Stu1 Marks', 'Student2', 'stu2 Marks', 'Student3', 'Stu3 Marks'])

# %%
list(d.values())
# Out:
# ['Roshan', 100, 'Lokesh', 202, 'Vikash', 303]

# %%
d
# Out:
# {'Student1': 'Roshan',
#  'Stu1 Marks': 100,
#  'Student2': 'Lokesh',
#  'stu2 Marks': 202,
#  'Student3': 'Vikash',
#  'Stu3 Marks': 303}

# %%
d.update({"Stu4": "Atultit Kashyap"})

# %%
d
# Out:
# {'Student1': 'Roshan',
#  'Stu1 Marks': 100,
#  'Student2': 'Lokesh',
#  'stu2 Marks': 202,
#  'Student3': 'Vikash',
#  'Stu3 Marks': 303,
#  'Stu4': 'Atultit Kashyap'}

# %%
d.update({"stu4 Marks": 400})

# %%
d
# Out:
# {'Student1': 'Roshan',
#  'Stu1 Marks': 100,
#  'Student2': 'Lokesh',
#  'stu2 Marks': 202,
#  'Student3': 'Vikash',
#  'Stu3 Marks': 303,
#  'Stu4': 'Atultit Kashyap',
#  'stu4 Marks': 400}

# %%
d1= {"MOhan": 300, "radha": 308, "Hari": 390, "Vikas": 380, "Venky":290}

# %%
d1.keys()
# Out:
# dict_keys(['MOhan', 'radha', 'Hari', 'Vikas', 'Venky'])

# %%
d1.values()
# Out:
# dict_values([300, 308, 390, 380, 290])

# %%
d1
# Out:
# {'MOhan': 300, 'radha': 308, 'Hari': 390, 'Vikas': 380, 'Venky': 290}

# %%
Stu_name = input("enter a name")
if Stu_name in d1 :
    print(f"{Stu_name} s marks: {d1[Stu_name]}")
else:
    print("Student not found")
# Out:
# Student not found

# %%
S1= {5,4,4,5,6,6,67,7,2,3,4,5,6,9,7}

# %%
S1
# Out:
# {2, 3, 4, 5, 6, 7, 9, 67}

# %%
S1.add(50)

# %%
S1
# Out:
# {2, 3, 4, 5, 6, 7, 9, 50, 67}

# %%
S1.add(50)

# %%
S1
# Out:
# {2, 3, 4, 5, 6, 7, 9, 50, 67}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}

# %%
s3 = set1+set2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 s3 = set1+set2
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
result_union = set1 | set2

# %%
result_union
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
result = set1&set2

# %%
result
# Out:
# {3, 4}

# %%
difference = set1 - set2

# %%
difference
# Out:
# {1, 2}

# %%
dif1 = set2 - set1

# %%
dif1
# Out:
# {5, 6}

# %%
print(difference)
print (dif1)
# Out:
# {1, 2}
# {5, 6}

# %%
print(difference), print (dif1)
# Out:
# {1, 2}
# {5, 6}
# (None, None)

# %%
l1 = [3,4,5,6,4,5,8,77,8,90,3,2,6,34,8]

# %%
set[l1]
# Out:
# set[[3, 4, 5, 6, 4, 5, 8, 77, 8, 90, 3, 2, 6, 34, 8]]

# %%
set(l1)
# Out:
# {2, 3, 4, 5, 6, 8, 34, 77, 90}
