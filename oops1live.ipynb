# %%
2
# Out:
# 2

# %%
class order:
    def __init__(self,cart_total,dist_km):
        self.cart_total = cart_total
        self.dist_km = dist_km
        
    def delivery_fee(self):
        base = 20
        per_km = 5
        total_charge = per_km*self.dist_km + base
        return total_charge
    
    def fianl_amount(self):
        return self.cart_total + self.delivery_fee()

# %%
class freedeliverypass(order):
    def delivery_fee_pass(self):
        if self.cart_total >1000:
            return 0
        return super().delivery_fee()

# %%
class rainsurge(order):
    def delivery_fee_rain(self):
        base_fee =  super().delivery_fee()
        surge_amount = .25 * base_fee
        return base_fee + surge_amount

# %%
o2 = order(2000,7)

# %%
o2.delivery_fee()
# Out:
# 55

# %%
o2.fianl_amount()
# Out:
# 2055

# %%
o3 = freedeliverypass(900, 25)

# %%
o3.delivery_fee_pass()
# Out:
# 145

# %%
o3.fianl_amount()
# Out:
# 1045

# %%
o4 =rainsurge(400,17)

# %%
o4.delivery_fee_rain()
# Out:
# 131.25

# %%
o4.fianl_amount()
# Out:
# 505

# %%
class  father:
    def show_father (self ):
        print("father nature : hardworking, discipine")

    def show_mother (self):

# %%
class order :
    def __init__(self, cart_total, dist_km):
        self.cart_total = cart_total
        self.dist_km = dist_km

    def deliver_fee(self):
        base = 20
        per_km = 5
        total_charge =per_km*self.dist_km +base
        return total_charge
    
    def final_amount (self):
        return self.cart_total + self.deliver_fee()

# %%
class freedeliverypass(order):
   def deliver_fee(self):
        if self.cart_total > 1000:
            return 0
        return super().deliver_fee()

# %%
class raisesurge (order):
    def deliver_fee(self):
        base_fee = super().deliver_fee()
        surge_amount = .25 *base_fee
        return base_fee+ surge_amount

# %%
o1 = order(2000, 12)

# %%
o1.deliver_fee()
# Out:
# 80

# %%
o1.final_amount()
# Out:
# 2080

# %%
o2 = freedeliverypass(800,15)

# %%
o3= raisesurge(500, 16)

# %%
o3.deliver_fee()
# Out:
# 100

# %%
o3.delivery_fee_rain()
# Out:
# 125.0

# %%
o3.final_amount()
# Out:
# 625.0

# %%
class Fahter :
    def show_father(self):
        print(f"Father nature : hardworking, disciplined")

class Mother :
    def show_mother(self):
        print(f"mother nature : caring, intelligent")

class child(Fahter, Mother):
    def show_father(self):
        return super().show_mother()

# %%
ch1 = child()

# %%
ch1.show_father()
# Out:
# mother nature : caring, intelligent

# %%
class grandfather:
    def show_grandfahter (self):
        print(f"i am you gradfather")

class Father(grandfather):
    def show_father(self):
        print(f"i am you father")

class child(Father):
    def show_child(self):
        print (f"i am you child ")
    
class childofchild(child):
    def show_childofchild(self):
        return super().

# %%
ch2 = child()
ch2.show_father()
# Out:
# i am you gradfather
