# %%
1
# Out:
# 1

# %%
class Animal:
    def sound(self):
        print(f"Dog : Barks")

class Dog(Animal):
    def sound(self):
        print("Bark")

# %%
d1 = Dog()

# %%
d1.sound()
# Out:
# Bark

# %%
class animal :
    def sound(self):
        print(f" Animal sound")

class dog(animal):
    def sound(self):
        print(f"Bark")

# %%
D1 = dog()

# %%
D1.sound()
# Out:
# Bark

# %%
class vehicle :
    def brand_model (self, honda, city):
        self.honda =honda
        self.city = city

class car(vehicle):
    def brand_model (self, ):
        return 4

# %%
c1 = car()

# %%
c1.number_of_doors()
# Out:
# 4

# %%
clear

# %%
class Vehicle:
    def __init__ (self,brand, model):
        self.brand = brand
        self.model = model

class car(Vehicle):
    def __init__(self, brand, model, door):
        super().__init__(brand, model)
        self.door = door

    def display (self):
        print(f"Brand : {self.brand}- Model : {self.model}- {self.door}")

    

c1 = car("Toyota", "Fortuner", 4)
c1.display()
# Out:
# Brand : Toyota- Model : Fortuner- 4

# %%
c1 = car("Toyota", "Fortuner", 4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 c1 = car("Toyota", "Fortuner", 4)
#
# TypeError: car() takes no arguments

# %%
class vehicle:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

class car(vehicle):
    def __init__(self, brand, model, door):
        super().__init__(brand, model)
        self.door = door

    
    def display(self):
        print(f"{self.brand}- {self.model}- {self.door}")

car1 = car("Maruti Suzuki", "Baleno", 4)
car1.display()
# Out:
# Maruti Suzuki- Baleno- 4

# %%
class person :
    def __init__(self, name , age):
        self.name = name
        self.age = age

    
class student(person) :
        def __init__(self, name, age, roll_no):
            super().__init__(name, age)
            self.roll_no = roll_no



        def display(self):
             print(f"{self.name}- {self.age}- {self.roll_no}")

s1 = student("Abhishek Kumar", 34, "A80")
s1.display()
# Out:
# Abhishek Kumar- 34- A80

# %%
class Shape:
    def __init__(self):
        pass

# %%
class shape:
    def area (self):
        return 0
    
class circle :
    def __init__(self, radius):
        self.radius = radius

    
    def area(self):
        return 3.14 * self.radius * self.radius

# %%
c = circle(200)
print ("Area of circle :", c.area())
# Out:
# Area of circle : 125600.0

# %%
class Employee:
    def __init__(self, department):
        self.department = department
    
class Manager (Employee):
    def __init__(self, department, name):
        super().__init__(department)
        self.name = name

    
    def display(self):
        print(f"{self.name}-{self.department}")

# %%
d1 = Manager("Dr. Kirti Uidayai", "public health")
d1.display()
# Out:
# public health-Dr. Kirti Uidayai

# %%
class Animal:
    def move(self):
        print("Animal can move")

class bird(Animal):
    def move(self):
        print("Bird can fly")

# %%
a= Animal()
b= bird()

# %%
a.move()
# Out:
# Animal can move

# %%
b.move()
# Out:
# Bird can fly

# %%
class device:
    def __init__(self, brand, model, feature ):
        self.model = model
        self.brand = brand
        self.feature = feature

class laptop(device):
        def __init__(self, brand, model, feature):
             super().__init__(brand, model, feature)

    
        def display(self):
             print (f"{self.brand}- {self.model}- {self.feature}")

# %%
l1 = laptop("dell", "XPS 13 plus", "compact, OLED Display")

# %%
l1.display()
# Out:
# dell- XPS 13 plus- compact, OLED Display

# %%
class Human:
    def show_human(self):
        print("i am human and boss")
class Employee(Human):
    def show_human (self):
        print(" i am your employee")

class Programmer (Employee):
    def show_human(self):
        return super().show_human()

# %%
class human:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def show_human(self):
        print(f"Name :{self.name}, Age : {self.age}")

class employee(human):
    def __init__(self, name, age, employee_id, salary):
        super().__init__(name, age)
        self.employee_id = employee_id
        self.salary = salary

    def show_employee(self):
        print(f"Employee id : {self.employee_id}, Salary : {self.salary}")

class progammer(employee):
    def __init__(self, name, age, employee_id, salary, language):
        super().__init__(name, age, employee_id, salary)
        self.language = language

    def show_programmer(self):
        self.show_human()
        self.show_employee()    
        print(f"Language: {self.language}")
              
              

p1 = progammer("Chitranjan Kumar", 35,"C201", 150000, "Python")

# %%
p1.show_programmer()
# Out:
# Name :Chitranjan Kumar, Age : 35
# Employee id : C201, Salary : 150000
# Language: Python

# %%
class father:
    def skill (self):
        return "Hardworking & Decipline"

class mother:
    def skill (self):
        return "Sinciere, Fine cooking & Dancer"
        

class child(father, mother):
    def show_skill(self):
        print(f"Child had inherited from:")
        print("Father: ", father().skill())
        print("Mother : ", mother().skill())
        print("Chld adds: Running, Cricket")

# %%
ch1 = child()
ch1.show_skill()
# Out:
# Child had inherited from:
# Father:  Hardworking & Decipline
# Mother :  Sinciere, Fine cooking & Dancer
# Chld adds: Running, Cricket

# %%
class Father:
    def skill(self):
        return "Hardworking & Discipline"

class Mother:
    def skill(self):
        return "Sincere, Fine cooking & Dancer"

class Child(Father, Mother):
    def show_skill(self):
        print("Child has inherited skills from:")
        print("Father:", Father().skill())
        print("Mother:", Mother().skill())
        print("Child adds: Running, Cricket")

c = Child()
c.show_skill()
# Out:
# Child has inherited skills from:
# Father: Hardworking & Discipline
# Mother: Sincere, Fine cooking & Dancer
# Child adds: Running, Cricket

# %%
class food:
    def eat (self):
        return "A Balance diet & nutritious food can assure health life"
    
class vegetarian(food):
    def eat (self):
        return "A veg food combine leaf,root,sids,grains and fruits"
    
class nonvegetarian(food):
    def eat (self):
        return " Non veg food combine all type of meat"
    
    
f = food()
v = vegetarian()
n = nonvegetarian()

print("Food:", f.eat())
print("Vegetarian:", v.eat())
print("Novegetarian:", n.eat())
# Out:
# Food: A Balance diet & nutritious food can assure health life
# Vegetarian: A veg food combine leaf,root,sids,grains and fruits
# Novegetarian:  Non veg food combine all type of meat

# %%
f1= vegetarian
f1.eat()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 2
#       1 f1= vegetarian
# ----> 2 f1.eat()
#
# TypeError: vegetarian.eat() missing 1 required positional argument: 'self'

# %%
class father:
    def skill (self):
        return "Athelete , Mountainer"
    
class mother:
    def skill (self):
        return "Cooking , Dressing sence"
class child(father, mother):
    def show_skill(self):
        print("Child inherit skill from paretns :")
        print("Father :", father().skill())
        print("Mother :", mother().skill())
        print("Child :", "Football", "& " "Love to play in Park")

# %%
ch1 = child()
ch1.show_skill()
# Out:
# Child inherit skill from paretns :
# Father : Athelete , Mountainer
# Mother : Cooking , Dressing sence
# Child : Football & Love to play in Park

# %%
class bankaccount:
    def __init__(self, acc_name, acc_num, balance =0 ):
        self.acc_name= acc_name
        self.acc_num = acc_num 
        self. balance= balance


    def deposit(self,amount):
        self.balance += amount
        print(f"Depost Amount : {amount}. New Balance: {self.balance}")

    def display_balance(self):
        print(f"Name : {self.acc_name} -Acc no :{self.acc_num}- Balance : {self.balance} ")

class savingaccount(bankaccount):
    def __init__(self, acc_num, balance, interest_rate):
        super().__init__(acc_num, balance)
        self.interest_rate = interest_rate


    def apply_interest(self):
        interest = self.balance *(self.interest_rate / 100)
        self.balance += interest
        print(f"Interest ₹{interest}- added. Upadated balance :₹{self.balance} ")

# %%
acc1 = savingaccount("sbi091", 5000, 5)
acc1.display_balance()
acc1.deposit(2000)
acc1.apply_interest()
acc1.display_balance
# Out:
# Name : sbi091 -Acc no :5000- Balance : 0
# Depost Amount : 2000. New Balance: 2000
# Interest ₹100.0- added. Upadated balance :₹2100.0
# <bound method bankaccount.display_balance of <__main__.savingaccount object at 0x00000207DB833390>>

# %%
acc1 = savingacc()

# %%
acc1.deposit(500)
# Out:
# 500

# %%
acc1.balance()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 acc1.balance()
#
# TypeError: 'int' object is not callable

# %%
class email:
    def send(self, message):
        print (f"this is your email {message}")

class sms:
    def send(self,message):
        print(f"this is your sms {message}")
class notificaiton :
    def send(self, message):
        print(f"this is your notification{message}")

# %%
channel = [email(), sms(), notificaiton()]

# %%
def notify_all(channel, message):
    for ch in channel:
        ch.send(message)

# %%
notify_all (channel, "today i am coding on inheritence and it is quit tough")
# Out:
# this is your email today i am coding on inheritence and it is quit tough
# this is your sms today i am coding on inheritence and it is quit tough
# this is your notificationtoday i am coding on inheritence and it is quit tough

# %%
class libraritem:
    def item (self):
        return "Library is having saveral books and magzine"
    
class book(libraritem):
    def item(self):
        return "Book contains like communication, health information, AI/ML"
    
class magazine(libraritem):
    def item(self):
        return "Magazine contains weekly india today , educaiton, health research etc"

# %%
l = libraritem()
b = book()
m = magazine()

# %%
print("Library :", l.item())
print("Book:", b.item())
print("Magazine :", b.item())
# Out:
# Library : Library is having saveral books and magzine
# Book: Book contains like communication, health information, AI/ML
# Magazine : Book contains like communication, health information, AI/ML

# %%
class libraritem:
    def __init__(self, title, year):
        self.title = title
        self.year = year

    def show_details(self):
        return f"Title :{self.title} - Year: {self.year}"
        
class book(libraritem):
    def __init__(self,title, year, author):
        super().__init__(title, year)
        self.author = author
    
    def show_details(self):
        return f"Book - {self.author}, Year : {self.year}, Author : {self.author}"
        

class magazine (libraritem):
    def __init__(self, title, year, issue):
        super().__init__(title,year)
        self.issue = issue

    def show_details(self):
        return f" Mazagine -{self.title}, Issue: {self.issue}, Year : {self.year}"

# %%
b1 = book("Python basis", 2025, "Sudanshu Trivedi")
m1 = magazine("Education update", "2024", "NOvember edition" )

# %%
print(b1.show_details())
print(m1.show_details())
# Out:
# Book - Sudanshu Trivedi, Year : 2025, Author : Sudanshu Trivedi
#  Mazagine -Education update, Issue: NOvember edition, Year : 2024

# %%
class person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        
class teacher(person):
    def __init__(self, name, age, subject):
        super().__init__(name, age)
        self.subject = subject

    
    def display(self):
        print(f"{self.name}- {self.age}- {self.subject}")
        
t1 = teacher("Rakesh Singh Joshi", 55, "Big Data Analysis")

# %%
t1.display()
# Out:
# Rakesh Singh Joshi- 55- Big Data Analysis

# %%
class vehicle :
    def __init__(self,type, uses):
        self.type = type
        self.uses = uses

    def v_display(self):
        print(f"{self.type}- {self.uses}")
        
class car(vehicle):
    count = 0

    def __init__(self, type, uses, pur_year):
        super().__init__(type, uses)
        self.pur_year = pur_year
        car.count += 1

    def c_car(self):
        print(f"{self.type}-{self.uses}- {self.pur_year}")

class bus(vehicle):
    count = 0

    def __init__(self, type, uses, route):
        super().__init__(type, uses)
        self.route = route
        bus.count += 1

    def b_display(self):
        print(f"{self.type}- {self.uses}- {self.route}")


b1 = bus("Public bus", "Public use", "Barachatti- Gaya")
c1 = car("Own car", "Personal use", 2022)
c1 = car("Public car", "Public use", 2000)

print("Total car:", car.count)
print("Total bus:", bus.count)
# Out:
# Total car: 2
# Total bus: 1

# %%
b1.b_display()
# Out:
# Public bus- Public use- Barachatti- Gaya

# %%
c1.c_car()
# Out:
# Own car-Personal use- 2022

# %%
class student:
    def __init__(self,name, roll_no):
        self.name = name
        self.roll_no = roll_no

    def display_stu(self):
        print (f"{self.name} - {self.roll_no}")

class marks(student):
    def __init__(self, name, roll_no, m1, m2, m3):
        super().__init__(name, roll_no)
        self.m1 = m1
        self.m2 = m2
        self.m3 = m3

    def calculate_total (self):
        return self.m1+self.m2+self.m3
    
    def grade(self):
        total = self.calculate_total()
        avg = total / 3
        if avg >= 90:
            return "A+"
        elif avg >=75:
            return "B"
        elif avg >=60:
            return "C"
        elif avg >= 45:
            return "D"
        else:
            return "Fail!!"

    def display_result(self):
        self.display_stu()
        print(f"Marks: {self.m1}, {self.m2}, {self.m3}")
        print(f"Total Number: {self.calculate_total()}")
        print(f"Graded: {self.grade()}")

s1 = marks("Chitranjan Kumar", "A101", 80, 90, 85)

# %%
s1.display_result()
# Out:
# Chitranjan Kumar - A101
# Marks: 80, 90, 85
# Total Number: 255
# Graded: B

# %%
class account:
    def __init__(self, acc_hol_name, acc_num, balance= 0):
        self.acc_hol_name = acc_hol_name
        self.acc_num = acc_num
        self.balance = balance

    def depsoit (self,amount):
        self.balance += amount
        self.amount = amount
        print(f"Deposit = {self.amount},New balance = {self.balance}")

    def display_balance(self):
        print(f"{self.acc_hol_name}, {self.acc_num}, {self.balance}")

    def withdraw(self):
       withdraw = self.balance - self.amount
   

class salaryaccount(account):
    def __init__(self, acc_hol_name, acc_num, balance=0, limit ):
        super().__init__(acc_hol_name, acc_num, balance)
        self.limit = limit

    def limit (self):
        if self.balance <1000:
            return "You can not withdraw amount"
        else:
            print(f"{withdraw}")
# Out:
#   Cell In[37], line 20
#     def __init__(self, acc_hol_name, acc_num, balance=0, limit ):
#                                                          ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
class bankaccount:
    def __init__(self, acc_num, balance ):
        self.acc_num = acc_num 
        self. balance= balance

    def withdraw(self, amount):
        if amount <=self.balance :
            self.balance-=amount
            print(f"Withdraw successful ! New Balance :{self.balance}")
        else:
            print(f"Insufficient balance")


class salaryaccount(bankaccount):
    def __init__(self, acc_num, balance, limit):
        super().__init__(acc_num, balance)
        self.limit = limit

    
    def withdraw(self, amount):
        if amount >self.limit:
            print(f"Withdraw denied !limit is{self.limit}")
        elif amount > self.balance:
            print(f"INsufficient balance")
        else:
            self.balance-=amount
            print(f"Withdraw successful! Rrmaining balance is{self.balance}")

# %%
s1 = salaryaccount(2304503958, 50000, 20000 )

# %%
s1.withdraw(15000)
# Out:
# Withdraw successful! Rrmaining balance is35000

# %%
s1.withdraw(500006)
# Out:
# Withdraw denied !limit is20000

# %%
s1.withdraw(6000000)
# Out:
# Withdraw denied !limit is20000

# %%
class parents:
    def behaviour (self):
        return "Parents are well mannered and discipline"

class child(parents):
    def behaviour(self):
        return "Child love to play and explore new things"

# %%
p = parents()
c = child()

# %%
p.behaviour()
# Out:
# 'Parents are well mannered and discipline'

# %%
c.behaviour()
# Out:
# 'Child love to play and explore new things'

# %%
class animal:
    def sound(self):
        pass
class dog(animal):
    def sound(self):
        return " Dog Barks"
    
class cat(animal):
    def sound(self):
        return "Cat do meow"
class cow(animal):
    def sound(self):
        return "cow do mo mo"
    

animals = [dog(), cat(), cow()]

for i in animals:
    print(i.sound())
# Out:
#  Dog Barks
# Cat do meow
# cow do mo mo

# %%
d = dog()
c = cat()
c1 = cow()

# %%
print(d.sound())
print(c.sound())
print(c1.sound())
# Out:
#  Dog Barks
# Cat do meow
# cow do mo mo

# %%
class employee:
    def work (self):
        pass
class developer(employee):
    def work (self):
        return "Developer develop the structure of the project"
class designer(employee):
    def work(self):
        return "Designer design the system of project and set up system workflow"
class manager(employee):
    def work (self):
        return "Manager manage the work and check project activity and fulfillnes of work on time"

company = [developer(), designer(), manager()]

for co in company:
    print(co.work())
# Out:
# Developer develop the structure of the project
# Designer design the system of project and set up system workflow
# Manager manage the work and check project activity and fulfillnes of work on time

# %%
class payment:
    def pay (self):
        pass

class creditard(payment):
    def pay (self):
        return "Credicaed mehtod is to make payment by using card only"
    
class UPI(payment):
    def pay(self):
        return "UPI is the method is to pay via using mobie app (phonpay/paytm) etc"
    
class netbanking(payment):
    def pay(self):
        return "Netbanking is the method to pay via using bank website only"
    
method = [creditard(), UPI(), netbanking()]

for me in method:
    print(me.pay())
# Out:
# Credicaed mehtod is to make payment by using card only
# UPI is the method is to pay via using mobie app (phonpay/paytm) etc
# Netbanking is the method to pay via using bank website only
